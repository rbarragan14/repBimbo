# %% [markdown]
# # Comprobar predicciones Batch
#
# En este notebook vamos a consultar las prediciones realizadas en el modo batch. Para ello usaremos el kernel de **Teradata SQL**.
#
# ## Crear la conexión a Teradata Vantage

# %%
%var systemName="Vantage POC", user="aoa_service", host="13.68.232.78", db="aoa_data"

# %%
%addconnect name=${systemName}, user=${user}, host=${host}
# Out:
# Connection with the name 'Vantage POC' already exists

# %%
%connect ${systemName}
# Out:
# Password: ···········
# Success: 'Vantage POC' connection established and activated for user 'aoa_service'

# %% [markdown]
# #### Establecemos la base de datos de Vantage

# %%
DATABASE ${db}
# Out:
# Success: 1 rows affected

# %% [markdown]
# ## Comprobar las predicciones
#
# Para ejecutamos la siguiente consulta

# %%
SELECT * FROM aoa_data.ACC_PREDICTIONS;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory544054"><style>
#       table.tdhistory544054 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory544054 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory544054:last-child { text-align: left !important; }
#       tbody.tdhistory544054 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory544054 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory544054 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory544054"></th><th class="tdhistory544054">prediction</th><th class="tdhistory544054">id</th></tr></thead><tbody class="tdhistory544054 resultset-body"><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory544054">1</td><td class="tdhistory544054">1</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory544054">1</td><td class="tdhistory544054">141</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory544054">0</td><td class="tdhistory544054">257</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory544054">0</td><td class="tdhistory544054">363</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory544054">0</td><td class="tdhistory544054">423</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory544054">1</td><td class="tdhistory544054">458</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory544054">1</td><td class="tdhistory544054">514</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory544054">1</td><td class="tdhistory544054">574</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory544054">0</td><td class="tdhistory544054">762</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory544054">1</td><td class="tdhistory544054">789</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory544054">0</td><td class="tdhistory544054">851</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory544054">0</td><td class="tdhistory544054">995</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory544054">0</td><td class="tdhistory544054">1096</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory544054">0</td><td class="tdhistory544054">1140</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory544054">0</td><td class="tdhistory544054">1218</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory544054">1</td><td class="tdhistory544054">1386</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory544054">0</td><td class="tdhistory544054">1669</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory544054">0</td><td class="tdhistory544054">1827</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">19</th><td class="tdhistory544054">1</td><td class="tdhistory544054">1911</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">20</th><td class="tdhistory544054">0</td><td class="tdhistory544054">2156</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">21</th><td class="tdhistory544054">1</td><td class="tdhistory544054">2213</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">22</th><td class="tdhistory544054">0</td><td class="tdhistory544054">2348</td></tr><tr><th class="tdhistory544054" style= "background: rgba(243, 243, 243, 0.75)">23</th><td class="tdhistory544054">0</td><td class="tdhistory544054">2404</td></tr><tr><th class="tdhistory544054" style= "background: rgba( ...

# %% [markdown]
# ## Eliminar la tabla de predicciones
#
# Para asegurarnos que en la próxima ejecución no de lugar a dudas de que la predicción se ha realizado correctamente, debemos eliminar la tabla.

# %%
DROP TABLE aoa_data.ACC_PREDICTIONS;
# Out:
# Success: 15 rows affected

# %% [markdown]
# Copyright 2021 Teradata. All rights reserved.
